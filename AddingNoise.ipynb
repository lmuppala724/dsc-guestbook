# %% [markdown]
# <a href="https://colab.research.google.com/github/lmuppala724/dsc-guestbook/blob/master/AddingNoise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def poisson_noise(img, x):
  noisy_img = np.random.poisson(img*x)
  return noisy_img

# %%
import cv2

def noise(img, std):
  noise = np.random.randn(*img.shape)
  return img + noise*std, noise

# %%
import pandas as pd
import numpy as np
from PIL import Image
from numpy import asarray
from matplotlib import pyplot as plt

image = Image.open("/content/sample_data/flower-729512__340.jpg")

numpydata = asarray(image)
print(numpydata.shape)
poisson_img = poisson_noise(numpydata, 1/6)

gaussian_noise_imgs, n = noise(numpydata, 30)

plt.imshow(gaussian_noise_imgs.astype(np.int32), vmin=0, vmax=255)
plt.show()

plt.imshow(n)
plt.show()

plt.imshow(poisson_img*6)
plt.show()

image
# Out:
# (340, 514, 3)
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=514x340 at 0x7FCB8472EE90>
